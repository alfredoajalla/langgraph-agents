# %%
from typing import TypedDict

class State(TypedDict): 
    customer_name: str
    my_agent: int

state: State = {}
customer_name = state.get("customer_name", None)
print(customer_name)  # This will print None since "customer_name" is not set in the state dictionary.
